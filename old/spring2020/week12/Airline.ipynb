# %%
import pandas as pd
data = pd.read_csv("https://raw.githubusercontent.com/fivethirtyeight/data/master/airline-safety/airline-safety.csv")

# %% [markdown]
# # Tasks
# - Access with and without index
# - List top 10 flights with the most km flown
# - List bottom 10 flights
# - Find 10 flights with the mosts number of incidents between 85-99
# - For the above 10 flights, find their incidence rate between 00-14
# - Do a bar plot for the above two tasks
# - Reverse the above scenario
# - Plot histogram of the above data
# - Plot the mean and std -- error bars

# %%
data2 = data.sort_values('avail_seat_km_per_week', ascending=False).tail(10)
data2
# Out:
#                    airline  avail_seat_km_per_week  incidents_85_99  \
# 2    Aerolineas Argentinas               385803648                6
# 12       Austrian Airlines               358239823                1
# 35  Pakistan International               348563137                8
# 21                   El Al               335448023                1
# 44   Sri Lankan / AirLanka               325582976                2
# 0               Aer Lingus               320906734                2
# 25                Gulf Air               301379762                1
# 38         Royal Air Maroc               295705339                5
# 29           Kenya Airways               277414794                2
# 46                    TACA               259373346                3
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 2                       0                 0                1
# 12                      0                 0                1
# ...

# %%
data2 = data.sort_values('incidents_85_99', ascending=False).head(10)
data2
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 1                    Aeroflot*              1197672318               76
# 22          Ethiopian Airlines               488560643               25
# 19          Delta / Northwest*              6525658894               24
# 11                   American*              5228357340               21
# 51       United / Continental*              7139291291               19
# 52  US Airways / America West*              2455687887               16
# 5                   Air France              3004002661               14
# 16              China Airlines               813216487               12
# 31                  Korean Air              1734522605               12
# 24            Garuda Indonesia               613356665               10
#
#     fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 1                      14               128                6
# ...

# %%
data2[['airline', 'incidents_85_99', 'incidents_00_14']]
# Out:
#                        airline  incidents_85_99  incidents_00_14
# 1                    Aeroflot*               76                6
# 22          Ethiopian Airlines               25                5
# 19          Delta / Northwest*               24               24
# 11                   American*               21               17
# 51       United / Continental*               19               14
# 52  US Airways / America West*               16               11
# 5                   Air France               14                6
# 16              China Airlines               12                2
# 31                  Korean Air               12                1
# 24            Garuda Indonesia               10                4

# %%
data2 = data2[['incidents_85_99', 'incidents_00_14']] 
data2
# Out:
#     incidents_85_99  incidents_00_14
# 1                76                6
# 22               25                5
# 19               24               24
# 11               21               17
# 51               19               14
# 52               16               11
# 5                14                6
# 16               12                2
# 31               12                1
# 24               10                4

# %%
data2 = data.sort_values('incidents_85_99', ascending=False).head(10)
data2.set_index('airline', inplace=True)
data2 = data2[['incidents_85_99', 'incidents_00_14']] 
data2.plot.bar()

# %%
data['incidents_85_99'].plot(kind='hist')

# %%
data2[:10]
# Out:
#                             incidents_85_99  incidents_00_14
# airline
# Aeroflot*                                76                6
# Ethiopian Airlines                       25                5
# Delta / Northwest*                       24               24
# American*                                21               17
# United / Continental*                    19               14
# US Airways / America West*               16               11
# Air France                               14                6
# China Airlines                           12                2
# Korean Air                               12                1
# Garuda Indonesia                         10                4

# %%
data[['incidents_85_99', 'incidents_00_14']].mean().plot.bar(yerr=data[['incidents_85_99', 'incidents_00_14']].std())

# %%
data.std()
# Out:
# avail_seat_km_per_week    1.465317e+09
# incidents_85_99           1.103566e+01
# fatal_accidents_85_99     2.861069e+00
# fatalities_85_99          1.466911e+02
# incidents_00_14           4.544977e+00
# fatal_accidents_00_14     8.586837e-01
# fatalities_00_14          1.113328e+02
# dtype: float64
