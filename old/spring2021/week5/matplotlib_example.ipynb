# %%
# %matplotlib notebook
# %matplotlib notebook




# %matplotlib notebook will lead to interactive plots embedded within the notebook

# %matplotlib inline will lead to static images of your plot embedded in the notebook

# %%
import matplotlib.pyplot as plt

# %%
def sim_coin_toss(number_of_simulations):
    import random
    output = {}
#     output = {}.fromkeys(
#     ['HeadsCount', 'TailsCount'], 0)
    for i in range(number_of_simulations):
        toss = random.randint(0,1)
        
        if toss == 0:
            toss = 'Heads'
        else:
            toss = 'Tails'
            
        if toss not in output:
            output[toss] = 0
            
        output[toss] += 1
    
    return output

# %%
no_tosses = 888888
data = sim_coin_toss(no_tosses)

group_data = list(data.values())
group_names = list(data.keys())

fig, ax = plt.subplots()
ax.bar(group_names, group_data)
ax.set(xlabel='Coins', ylabel='Frequency',
       title=f'Simulation with {no_tosses} Coin Tosses')
# Out:
# <img src="data:image/png;base64,..." width="432">
# [Text(0.5, 0, 'Coins'),
#  Text(0, 0.5, 'Frequency'),
#  Text(0.5, 1.0, 'Simulation with 888888 Coin Tosses')]

# %%
# https://www.simplypsychology.org/boxplots.html

import matplotlib.pyplot as plt

# Fixing random state for reproducibility

# fake up some data
spread = [1,2,3,3, 51, 52, 53,53,]
center = [25, 23, 24, 27, 28, 29, 20, 35, 34, 45, 89, 34, 55]
data = spread + center
data.sort()

# %%
data
# Out:
# [1,
#  2,
#  3,
#  3,
#  20,
#  23,
#  24,
#  25,
#  27,
#  28,
#  29,
#  34,
#  34,
#  35,
#  45,
#  51,
#  52,
#  53,
#  53,
#  55,
#  89]

# %%
import statistics as st

print(st.mean(data))
print(st.median(data))
print(st.stdev(data))
print(st.variance(data))
# Out:
# 32.666666666666664
# 29
# 21.8273528705002
# 476.43333333333334

# %%
fig1, ax1 = plt.subplots()
ax1.set_title('Basic Plot')
ax1.boxplot(data);
# Out:
# <img src="data:image/png;base64,..." width="639.4666666666667">
