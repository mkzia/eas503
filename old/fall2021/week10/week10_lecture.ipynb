# %%
import sqlite3
from sqlite3 import Error

def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)    
    except Error as e:
        print(e)

    return conn

# %%
import sqlite3
from sqlite3 import Error
import mysql
import oracle
import mssql

def create_connection(database_name):
    
    if database_name == 'msyql':
        conn = mysql.connect(username=username, password=password, hostname='example.edu')
    elif database_name == 'oracle'
        conn = orcx.connect(username=username, password=password, hostname='example.edu')
    elif 'sqlite':
        conn = sqlite3.connect(db_file)
    return conn

# %%
import sqlite3
from sqlite3 import Error


def create_connection(db_file):
    conn = None
    try:
        conn = sqlite3.connect(db_file)
    except Error as e:
        print(e)

    return conn


db_conn = create_connection('exampledb_test.db')
print(db_conn)
# Out:
# <sqlite3.Connection object at 0x000001A72170F210>

# %%
def create_table(conn, create_table_sql):
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)

        
create_table_sql = """
    CREATE TABLE students 
        (last_name TEXT, 
        first_name TEXT, 
        username TEXT, 
        exam1 REAL, 
        exam2 REAL, 
        exam3 REAL);"""

create_table(db_conn, create_table_sql)
# Out:
# table students already exists

# %%
db_conn.close()

# %%
def create_connection(db_file, delete_db=False):
    import os
    if delete_db and os.path.exists(db_file):
        os.remove(db_file)

    conn = None
    try:
        conn = sqlite3.connect(db_file)
        conn.execute("PRAGMA foreign_keys = 1")
    except Error as e:
        print(e)

    return conn

def create_table(conn, create_table_sql):
    try:
        c = conn.cursor()
        c.execute(create_table_sql)
    except Error as e:
        print(e)

def insert_student(conn, values):

    sql = ''' INSERT INTO students(last_name,first_name,username,exam1,exam2,exam3)
              VALUES(?,?,?,?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, values)
    return cur.lastrowid

# %%
db_conn.close()
db_conn = create_connection('students.db', True)

create_table_sql = """
    CREATE TABLE students 
        (last_name TEXT, 
        first_name TEXT, 
        username TEXT, 
        exam1 REAL, 
        exam2 REAL, 
        exam3 REAL);"""

create_table(db_conn, create_table_sql)

with db_conn: 
    with open('students.tsv') as file:
        for line in file:
            if not line.strip():
                continue
            values = line.strip().split('\t')
        
            rowid = insert_student(db_conn, values)

# %%
x = [1, 2, 3]
y = [3, 4, 5]

for x, y in zip(x,y):
    z = x+y
    print(z)
# Out:
# 4
# 6
# 8

# %%
x = [1, 2, 3]
y = [3, 4, 5]

for i in x:
    for j in y:
        z = i+j
        print(z)
# Out:
# 4
# 5
# 6
# 5
# 6
# 7
# 6
# 7
# 8

# %%
db_conn.close()
db_conn = create_connection('students.db', True)

create_table_sql = """
    CREATE TABLE students 
        (last_name TEXT, 
        first_name TEXT, 
        username TEXT, 
        exam1 REAL, 
        exam2 REAL, 
        exam3 REAL);"""

create_table(db_conn, create_table_sql)

val_list = []

with open('students.tsv') as file:
    for line in file:
        if not line.strip():
            continue
        values = line.strip().split('\t')
        val_list.append(values)

with db_conn:
    for values in val_list:
        rowid = insert_student(db_conn, values)



db_conn.close()

# %%
def execule_sql_select_statment(conn, sql_statment):
    cur = conn.cursor()
    cur.execute(sql_statment)

#     rows = cur.fetchall()
    rows = cur.fetchone()
    return rows

db_conn = create_connection('students.db')

sql_statment = 'SELECT last_name FROM Students;'

rows = execule_sql_select_statment(db_conn, sql_statment)

# %%
print(rows)
# Out:
# ('Larson',)

# %%
sql_statment = 'SELECT last_name FROM Students;'

rows = execule_sql_select_statment(db_conn, sql_statment)

# %%
for row in rows:
    print(row[0])
# Out:
# Larson
# Novak
# Sawyer
# Schultz
# Vega
# Adams
# Thompson
# Booth
# Gallegos
# Munoz
# Carey
# Paul
# Reed
# Parsons
# Mcclain
# Oliver
# Lozano
# Klein
# Brooks
# Lee
# Myers
# Bowen
# Gibson
# Smith
# Key
# Fleming
# Parrish
# Lewis
# Diaz
# Walter
# Bailey
# Terrell
# Johnson
# Lee
# Dominguez
# Ellis
# Wilkinson
# Rodriguez
# Kennedy
# Henderson
# Hill
# Jones
# Landry
# Cox
# Santana
# Patton
# Mclean
# Rhodes
# Ramsey
# Martin
# Perez
# Moran
# Kerr
# Wade
# Smith
# Long
# Ashley
# Patrick
# Oliver
# Hoffman
# Holden
# Graham
# Blair
# Taylor
# Reilly
# Gamble
# Weber
# Woodard
# Hull
# Frank
# Davis
# Baird
# Hensley
# Luna
# Garcia
# Andrews
# Watson
# Evans
# Barnes
# Nelson
# Patterson
# King
# Smith
# Cook
# Francis
# Monroe
# Cortez
# Chang
# Mcclain
# Sellers
# Olsen
# Melton
# Day
# Little
# Johnson
# Duncan
# Bush
# Summers
# Bowers
# Fernandez

# %%
sql_statment = 'SELECT * FROM Students WHERE last_name = "Duncan"'
rows = execule_sql_select_statment(db_conn, sql_statment)
print(rows)
# Out:
# [('Duncan', 'Andrew', 'duncanandr', 59.0, 87.0, 34.0)]

# %%
from IPython.display import display, HTML
import pandas as pd


sql_statement = "select * from students;"
df = pd.read_sql_query(sql_statement, db_conn)
display(df)
# Out:
#     last_name first_name       username  exam1  exam2  exam3
# 0      Larson    Melissa     larsonmeli   24.0   89.0   31.0
# 1       Novak    Melissa      novakmeli   77.0    3.0   38.0
# 2      Sawyer      Wendy     sawyerwend   81.0   59.0   30.0
# 3     Schultz     Marcus    schultzmarc   59.0   29.0   67.0
# 4        Vega   Nicholas       veganich   64.0   12.0   95.0
# ..        ...        ...            ...    ...    ...    ...
# 95     Duncan     Andrew     duncanandr   59.0   87.0   34.0
# 96       Bush  Alexander       bushalex   82.0   54.0   25.0
# 97    Summers    Michael    summersmich   18.0   95.0   63.0
# 98     Bowers     Sandra     bowerssand   52.0    8.0   50.0
# 99  Fernandez   Jonathan  fernandezjona   74.0   80.0   22.0
#
# [100 rows x 6 columns]

# %%
x = 1
print(x)

print((x, ))
# Out:
# 1
# (1,)

# %%
create_table_departments_sql = """ CREATE TABLE [Departments] (
    [DepartmentId] INTEGER  NOT NULL PRIMARY KEY,
    [DepartmentName] TEXT  NULL
); """

create_table_students_sql = """ CREATE TABLE [Students] (
    [StudentId] INTEGER  PRIMARY KEY NOT NULL,
    [StudentName] TEXT NOT NULL,
    [DepartmentId] INTEGER  NULL,
    [DateOfBirth] DATE NULL,
    FOREIGN KEY(DepartmentId) REFERENCES Departments(DepartmentId)
);  """



depts = ('IT', 'Physics', 'Arts', 'Math')
students = (
    ('Michael', 1, '1998-10-12'),
    ('John', 1, '1998-10-12'),
    ('Jack', 1, '1998-10-12'),
    ('Sara', 2, '1998-10-12'),
    ('Sally', 2, '1998-10-12'),
    ('Jena', None, '1998-10-12'),
    ('Nancy', 2, '1998-10-12'),
    ('Adam', 3, '1998-10-12'),
    ('Stevens', 3, '1998-10-12'),
    ('George', None, '1998-10-12')
)



def insert_depts(conn, values):
    sql = ''' INSERT INTO Departments(DepartmentName)
              VALUES(?) '''
    cur = conn.cursor()
    cur.execute(sql, values)
    return cur.lastrowid


def insert_student(conn, values):
    sql = ''' INSERT INTO Students(StudentName, DepartmentId, DateOfBirth)
              VALUES(?,?,?) '''
    cur = conn.cursor()
    cur.execute(sql, values)
    return cur.lastrowid

def select_all_students(conn):
    cur = conn.cursor()
    cur.execute("""SELECT * FROM Students INNER JOIN Departments USING(DepartmentId);""")

    rows = cur.fetchall()

    for row in rows:
        print(row)

    return rows

conn = create_connection('sqlite2.db', True)


with conn:
    create_table(conn, create_table_departments_sql)
    create_table(conn, create_table_students_sql)
    for value in depts:
        insert_depts(conn, (value, ))
    for values in students:
        insert_student(conn, values)
    select_all_students(conn)
conn.close()
# Out:
# (1, 'Michael', 1, '1998-10-12', 'IT')
# (2, 'John', 1, '1998-10-12', 'IT')
# (3, 'Jack', 1, '1998-10-12', 'IT')
# (4, 'Sara', 2, '1998-10-12', 'Physics')
# (5, 'Sally', 2, '1998-10-12', 'Physics')
# (7, 'Nancy', 2, '1998-10-12', 'Physics')
# (8, 'Adam', 3, '1998-10-12', 'Arts')
# (9, 'Stevens', 3, '1998-10-12', 'Arts')

# %%
conn = create_connection('sqlite2.db')
sql_statement = """
SELECT Students.StudentName, Departments.DepartmentName FROM Students JOIN Departments USING(DepartmentId);
"""
df = pd.read_sql_query(sql_statement, conn)
display(df)
# Out:
#   StudentName DepartmentName
# 0     Michael             IT
# 1        John             IT
# 2        Jack             IT
# 3        Sara        Physics
# 4       Sally        Physics
# 5       Nancy        Physics
# 6        Adam           Arts
# 7     Stevens           Arts

# %%
select_all_students(conn)
# Out:
# (1, 'Michael', 1, '1998-10-12', 'IT')
# (2, 'John', 1, '1998-10-12', 'IT')
# (3, 'Jack', 1, '1998-10-12', 'IT')
# (4, 'Sara', 2, '1998-10-12', 'Physics')
# (5, 'Sally', 2, '1998-10-12', 'Physics')
# (7, 'Nancy', 2, '1998-10-12', 'Physics')
# (8, 'Adam', 3, '1998-10-12', 'Arts')
# (9, 'Stevens', 3, '1998-10-12', 'Arts')
# [(1, 'Michael', 1, '1998-10-12', 'IT'),
#  (2, 'John', 1, '1998-10-12', 'IT'),
#  (3, 'Jack', 1, '1998-10-12', 'IT'),
#  (4, 'Sara', 2, '1998-10-12', 'Physics'),
#  (5, 'Sally', 2, '1998-10-12', 'Physics'),
#  (7, 'Nancy', 2, '1998-10-12', 'Physics'),
#  (8, 'Adam', 3, '1998-10-12', 'Arts'),
#  (9, 'Stevens', 3, '1998-10-12', 'Arts')]

# %%
def get_dept_fk(dept):
    cur = conn.cursor()
    cur.execute("""SELECT DepartmentId FROM Departments WHERE DepartmentName == (?);""",  (dept, ))

    fk = cur.fetchone()
    if fk:
        return fk[0]
    else:
        return None

    
depts = ('IT', 'Physics', 'Arts', 'Math')
students = (
    ('Michael', 'IT', '1998-10-12'),
    ('John', 'IT', '1998-10-12'),
    ('Jack', 'IT', '1998-10-12'),
    ('Sara', 'Physics', '1998-10-12'),
    ('Sally', 'Physics', '1998-10-12'),
    ('Jena', None, '1998-10-12'),
    ('Nancy', 'Physics', '1998-10-12'),
    ('Adam', 'Arts', '1998-10-12'),
    ('Stevens', 'Arts', '1998-10-12'),
    ('George', None, '1998-10-12')
)
conn.close()
conn = create_connection('sqlite2.db', True)


with conn:
    create_table(conn, create_table_departments_sql)
    create_table(conn, create_table_students_sql)
    for value in depts:
        insert_depts(conn, (value, ))
    for values in students:
        print(values)
        did = get_dept_fk(values[1])
        values = list(values)
        values[1] = did
        print(values)
            
        insert_student(conn, values)
    
    #select_all_students(conn)
conn.close()
# Out:
# ('Michael', 'IT', '1998-10-12')
# ['Michael', 1, '1998-10-12']
# ('John', 'IT', '1998-10-12')
# ['John', 1, '1998-10-12']
# ('Jack', 'IT', '1998-10-12')
# ['Jack', 1, '1998-10-12']
# ('Sara', 'Physics', '1998-10-12')
# ['Sara', 2, '1998-10-12']
# ('Sally', 'Physics', '1998-10-12')
# ['Sally', 2, '1998-10-12']
# ('Jena', None, '1998-10-12')
# ['Jena', None, '1998-10-12']
# ('Nancy', 'Physics', '1998-10-12')
# ['Nancy', 2, '1998-10-12']
# ('Adam', 'Arts', '1998-10-12')
# ['Adam', 3, '1998-10-12']
# ('Stevens', 'Arts', '1998-10-12')
# ['Stevens', 3, '1998-10-12']
# ('George', None, '1998-10-12')
# ['George', None, '1998-10-12']

# %%
def get_dept_fk(conn):
    cur = conn.cursor()
    cur.execute("SELECT * FROM Departments")

    depts = {}
    for did, dname in cur.fetchall():
        depts[dname] = did
                
    return depts
 
conn = create_connection('sqlite2.db')
get_dept_fk(conn)
# Out:
# {'IT': 1, 'Physics': 2, 'Arts': 3, 'Math': 4}

# %%
depts = ('IT', 'Physics', 'Arts', 'Math')
students = (
    ('Michael', 'IT', '1998-10-12'),
    ('John', 'IT', '1998-10-12'),
    ('Jack', 'IT', '1998-10-12'),
    ('Sara', 'Physics', '1998-10-12'),
    ('Sally', 'Physics', '1998-10-12'),
    ('Jena', None, '1998-10-12'),
    ('Nancy', 'Physics', '1998-10-12'),
    ('Adam', 'Arts', '1998-10-12'),
    ('Stevens', 'Arts', '1998-10-12'),
    ('George', None, '1998-10-12')
)
conn.close()
conn = create_connection('sqlite3.db', True)

with conn:
    create_table(conn, create_table_departments_sql)
    create_table(conn, create_table_students_sql)
    for value in depts:
        insert_depts(conn, (value, ))

dept_dict = get_dept_fk(conn)
print(dept_dict)

with conn:
    for values in students:
        print(values)
        did = dept_dict.get(values[1], None)
        if did:
            values = list(values)
            values[1] = did
            print(values)
           
        insert_student(conn, values)
    
    #select_all_students(conn)
conn.close()
# Out:
# {'IT': 1, 'Physics': 2, 'Arts': 3, 'Math': 4}
# ('Michael', 'IT', '1998-10-12')
# ['Michael', 1, '1998-10-12']
# ('John', 'IT', '1998-10-12')
# ['John', 1, '1998-10-12']
# ('Jack', 'IT', '1998-10-12')
# ['Jack', 1, '1998-10-12']
# ('Sara', 'Physics', '1998-10-12')
# ['Sara', 2, '1998-10-12']
# ('Sally', 'Physics', '1998-10-12')
# ['Sally', 2, '1998-10-12']
# ('Jena', None, '1998-10-12')
# ('Nancy', 'Physics', '1998-10-12')
# ['Nancy', 2, '1998-10-12']
# ('Adam', 'Arts', '1998-10-12')
# ['Adam', 3, '1998-10-12']
# ('Stevens', 'Arts', '1998-10-12')
# ['Stevens', 3, '1998-10-12']
# ('George', None, '1998-10-12')

# %%
import pandas as pd
import sqlite3
conn = sqlite3.connect('example5.db')

sql_statement = "SELECT * FROM EMPLOYEES"
df = pd.read_sql_query(sql_statement, conn)
df.style.set_table_attributes('style="font-size: 12px"')
display(df)


sql_statement = "SELECT * FROM EMPLOYEES_PROJECTS"
df = pd.read_sql_query(sql_statement, conn)
df.style.set_table_attributes('style="font-size: 12px"')
display(df)

sql_statement = "SELECT * FROM PROJECTS"
df = pd.read_sql_query(sql_statement, conn)
df.style.set_table_attributes('style="font-size: 12px"')
display(df)
# Out:
#   EmployeeID Last_Name First_Name
# 0     EN1-26   O'Brien       Sean
# 1     EN1-33      Guya        Amy
# 2     EN1-35   Baranco     Steven
# 3     EN1-36    Roslyn  Elizabeth
# 4     EN1-38    Schaaf      Carol
# 5     EN1-40      Wing  Alexandra
#    EmployeeID  ProjectNum
# 0      EN1-26   30-452-T3
# 1      EN1-26   30-457-T3
# 2      EN1-26   31-124-T3
# 3      EN1-33   30-328-TC
# 4      EN1-33   30-452-T3
# 5      EN1-33   32-244-T3
# 6      EN1-35   30-452-T3
# 7      EN1-35   31-238-TC
# 8      EN1-36   35-152-TC
# 9      EN1-38   36-272-TC
# 10     EN1-40  31-238-TC2
# 11     EN1-40   31-241-TC
#    ProjectNum       ProjectTitle
# 0   30-452-T3        STAR manual
# 1   30-457-T3     ISO procedures
# 2   30-482-TC           Web site
# 3   31-124-T3  Employee handbook
# 4   31-238-TC     STAR prototype
# 5  31-238-TC2        New catalog
# 6   35-152-TC       STAR pricing
# 7   36-272-TC       Order system

# %%
display(df)
# Out:
#    ProjectNum       ProjectTitle
# 0   30-452-T3        STAR manual
# 1   30-457-T3     ISO procedures
# 2   30-482-TC           Web site
# 3   31-124-T3  Employee handbook
# 4   31-238-TC     STAR prototype
# 5  31-238-TC2        New catalog
# 6   35-152-TC       STAR pricing
# 7   36-272-TC       Order system

# %%
conn = sqlite3.connect('example5.db')

sql_statement = "SELECT * FROM EMPLOYEES"
df = pd.read_sql_query(sql_statement, conn)
df.style.set_table_attributes('style="font-size: 12px"')
display(df)

sql_statement = "SELECT * FROM EMPLOYEES_PROJECTS"
df = pd.read_sql_query(sql_statement, conn)
df.style.set_table_attributes('style="font-size: 12px"')
display(df)

sql_statement = "SELECT * FROM PROJECTS"
df = pd.read_sql_query(sql_statement, conn)
df.style.set_table_attributes('style="font-size: 12px"')
# Out:
#   EmployeeID Last_Name First_Name
# 0     EN1-26   O'Brien       Sean
# 1     EN1-33      Guya        Amy
# 2     EN1-35   Baranco     Steven
# 3     EN1-36    Roslyn  Elizabeth
# 4     EN1-38    Schaaf      Carol
# 5     EN1-40      Wing  Alexandra
#    EmployeeID  ProjectNum
# 0      EN1-26   30-452-T3
# 1      EN1-26   30-457-T3
# 2      EN1-26   31-124-T3
# 3      EN1-33   30-328-TC
# 4      EN1-33   30-452-T3
# 5      EN1-33   32-244-T3
# 6      EN1-35   30-452-T3
# 7      EN1-35   31-238-TC
# 8      EN1-36   35-152-TC
# 9      EN1-38   36-272-TC
# 10     EN1-40  31-238-TC2
# 11     EN1-40   31-241-TC
# <style type="text/css">
# </style>
# <table id="T_6bee6_" style="font-size: 12px">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >ProjectNum</th>
#       <th class="col_heading level0 col1" >ProjectTitle</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bee6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bee6_row0_col0" class="data row0 col0" >30-452-T3</td>
#       <td id="T_6bee6_row0_col1" class="data row0 col1" >STAR manual</td>
#     </tr>
#     <tr>
#       <th id="T_6bee6_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6bee6_row1_col0" class="data row1 col0" >30-457-T3</td>
#       <td id="T_6bee6_row1_col1" class="data row1 col1" >ISO procedures</td>
#     </tr>
#     <tr>
#       <th id="T_6bee6_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6bee6_row2_col0" class="data row2 col0" >30-482-TC</td>
#       <td id="T_6bee6_row2_col1" class="data row2 col1" >Web site</td>
#     </tr>
#     <tr>
#       <th id="T_6bee6_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6bee6_row3_col0" class="data row3 col0" >31-124-T3</td>
#       <td id="T_6bee6_row3_col1" class="data row3 col1" >Employee handbook</td>
#     </tr>
#     <tr>
#       <th id="T_6bee6_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6bee6_row4_col0" class="data row4 col0" >31-238-TC</td>
#       <td id="T_6bee6_row4_col1" class="data row4 col1" >STAR prototype</td>
#     </tr>
#     <tr>
#       <th id="T_6bee6_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6bee6_row5_col0" class="data row5 col0" >31-238-TC2</td>
#       <td id="T_6bee6_row5_col1" class="data row5 col1" >New catalog</td>
#     </tr>
#     <tr>
#       <th id="T_6bee6_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6bee6_row6_col0" class="data row6 col0" >35-152-TC</td>
#       <td id="T_6bee6_row6_col1" class="data row6 col1" >STAR pricing</td>
#     </tr>
#     <tr>
#       <th id="T_6bee6_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6bee6_row7_col0" class="data row7 col0" >36-272-TC</td>
#       <td id="T_6bee6_row7_col1" class="data row7 col1" >Order system</td>
#     </tr>
#   </tbody>
# </table>
